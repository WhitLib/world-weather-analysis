# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
# Import the citipy module to determine city based on latitude and longitude
from citipy import citipy
# Import the API key
from config import weather_api_key
# Import the requests library
import requests
# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime

# %%
# Create a set of random latitude and longitude combinations
lat = np.random.uniform(low=-90.000, high=90.000, size=2000)
lng = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lng = zip(lat, lng)
lat_lng

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lng)

# %%
# Create an empty cities list
cities =[]

# Identify the nearest city for each lat and long combination
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 762

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
#print(url)

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in our list.
for i in range(len(cities)):

    # Group cities in sets of 25 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + cities[i]
    
# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 25 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_desc = str(city_weather["weather"][0]["description"])
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                            "Lat": city_lat,
                            "Lng": city_lng,
                            "Max Temp": city_max_temp,
                            "Humidity": city_humidity,
                            "Cloudiness": city_clouds,
                            "Wind Speed": city_wind,
                            "Country": city_country,
                            "Date": city_date,
                            "Description": city_desc,})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 16 | hailin
# Processing Record 2 of Set 16 | ushuaia
# Processing Record 3 of Set 16 | constitucion
# Processing Record 4 of Set 16 | clyde river
# Processing Record 5 of Set 16 | castanos
# Processing Record 6 of Set 16 | albany
# Processing Record 7 of Set 16 | forestville
# Processing Record 8 of Set 16 | dingli
# Processing Record 9 of Set 16 | carnarvon
# Processing Record 10 of Set 16 | hilo
# Processing Record 11 of Set 16 | cape town
# Processing Record 12 of Set 16 | znamenskoye
# Processing Record 13 of Set 16 | hambantota
# Processing Record 14 of Set 16 | nikolskoye
# Processing Record 15 of Set 16 | airai
# Processing Record 16 of Set 16 | puerto ayora
# Processing Record 17 of Set 16 | kavieng
# Processing Record 18 of Set 16 | chapais
# Processing Record 19 of Set 16 | luderitz
# Processing Record 20 of Set 16 | flinders
# Processing Record 21 of Set 16 | iqaluit
# Processing Record 22 of Set 16 | pevek
# Processing Record 23 of Set 16 | isangel
# Processing Record 24 of Set 16 | faanui
# Processing Record 25 of Set 16 | mataura
# Processing Record 26 of Set 16 | hermanus
# Processing Record 27 of Set 16 | kaitangata
# Processing Record 28 of Set 16 | rocha
# Processing Record 29 of Set 16 | ipixuna
# Processing Record 30 of Set 16 | bredasdorp
# Processing Record 31 of Set 16 | olinda
# Processing Record 32 of Set 16 | palmer
# Processing Record 33 of Set 16 | solnechnyy
# Processing Record 34 of Set 16 | vaini
# Processing Record 35 of Set 16 | norman wells
# Processing Record 36 of Set 16 | ribeira grande
# Processing Record 37 of Set 16 | slavutych
# Processing Record 38 of Set 16 | new norfolk
# Processing Record 39 of Set 16 | imbituba
# Processing Record 40 of Set 16 | chokurdakh
# Processing Record 41 of Set 16 | noumea
# Processing Record 42 of Set 16 | victoria
# Processing Record 43 of Set 16 | samusu
# City not found. Skipping...
# Processing Record 44 of Set 16 | rikitea
# Processing Record 45 of Set 16 | barrow
# Processing Record 46 of Set 16 | uhlove
# Processing Record 47 of Set 16 | zhigansk
# Processing Record 48 of Set 16 | hinesville
# Processing Record 49 of Set 16 | parsabad
# Processing Record 50 of Set 16 | marcona
# City not found. Skipping...
# Processing Record 1 of Set 17 | port alfred
# Processing Record 2 of Set 17 | dikson
# Processing Record 3 of Set 17 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 4 of Set 17 | acapulco
# Processing Record 5 of Set 17 | kadykchan
# City not found. Skipping...
# Processing Record 6 of Set 17 | aleksandrow lodzki
# Processing Record 7 of Set 17 | narsaq
# Processing Record 8 of Set 17 | amderma
# City not found. Skipping...
# Processing Record 9 of Set 17 | tsihombe
# City not found. Skipping...
# Processing Record 10 of Set 17 | upernavik
# Processing Record 11 of Set 17 | torbay
# Processing Record 12 of Set 17 | butaritari
# Processing Record 13 of Set 17 | dakar
# Processing Record 14 of Set 17 | busselton
# Processing Record 15 of Set 17 | bluff
# Processing Record 16 of Set 17 | marquette
# Processing Record 17 of Set 17 | yantal
# Processing Record 18 of Set 17 | hamilton
# Processing Record 19 of Set 17 | dalbandin
# Processing Record 20 of Set 17 | saskylakh
# Processing Record 21 of Set 17 | kapaa
# Processing Record 22 of Set 17 | chuy
# Processing Record 23 of Set 17 | khonuu
# City not found. Skipping...
# Processing Record 24 of Set 17 | punta arenas
# Processing Record 25 of Set 17 | atuona
# Processing Record 26 of Set 17 | te anau
# Processing Record 27 of Set 17 | coahuayana
# Processing Record 28 of Set 17 | samarai
# Processing Record 29 of Set 17 | mehamn
# Processing Record 30 of Set 17 | kysyl-syr
# Processing Record 31 of Set 17 | sur
# Processing Record 32 of Set 17 | attawapiskat
# City not found. Skipping...
# Processing Record 33 of Set 17 | hobart
# Processing Record 34 of Set 17 | turukhansk
# Processing Record 35 of Set 17 | georgetown
# Processing Record 36 of Set 17 | pensacola
# Processing Record 37 of Set 17 | qaanaaq
# Processing Record 38 of Set 17 | bargal
# City not found. Skipping...
# Processing Record 39 of Set 17 | jamestown
# Processing Record 40 of Set 17 | lebu
# Processing Record 41 of Set 17 | saint-pierre
# Processing Record 42 of Set 17 | provideniya
# Processing Record 43 of Set 17 | talnakh
# Processing Record 44 of Set 17 | shingu
# Processing Record 45 of Set 17 | midleton
# Processing Record 46 of Set 17 | geraldton
# Processing Record 47 of Set 17 | tuktoyaktuk
# Processing Record 48 of Set 17 | manokwari
# Processing Record 49 of Set 17 | college
# Processing Record 50 of Set 17 | vila
# Processing Record 1 of Set 18 | bambous virieux
# Processing Record 2 of Set 18 | taolanaro
# City not found. Skipping...
# Processing Record 3 of Set 18 | mar del plata
# Processing Record 4 of Set 18 | ola
# Processing Record 5 of Set 18 | olafsvik
# Processing Record 6 of Set 18 | sept-iles
# Processing Record 7 of Set 18 | smirnykh
# Processing Record 8 of Set 18 | comodoro rivadavia
# Processing Record 9 of Set 18 | xining
# Processing Record 10 of Set 18 | saint-philippe
# Processing Record 11 of Set 18 | palu
# Processing Record 12 of Set 18 | barentsburg
# City not found. Skipping...
# Processing Record 13 of Set 18 | shimoda
# Processing Record 14 of Set 18 | leningradskiy
# Processing Record 15 of Set 18 | birobidzhan
# Processing Record 16 of Set 18 | east london
# Processing Record 17 of Set 18 | quatre cocos
# Processing Record 18 of Set 18 | san pedro
# Processing Record 19 of Set 18 | dubti
# Processing Record 20 of Set 18 | chivay
# Processing Record 21 of Set 18 | port-cartier
# Processing Record 22 of Set 18 | port hardy
# Processing Record 23 of Set 18 | kodiak
# Processing Record 24 of Set 18 | bowen
# Processing Record 25 of Set 18 | kruisfontein
# Processing Record 26 of Set 18 | svetlogorsk
# Processing Record 27 of Set 18 | cabo san lucas
# Processing Record 28 of Set 18 | sirawai
# Processing Record 29 of Set 18 | ankang
# Processing Record 30 of Set 18 | berdigestyakh
# Processing Record 31 of Set 18 | castro
# Processing Record 32 of Set 18 | phalombe
# Processing Record 33 of Set 18 | ponta do sol
# Processing Record 34 of Set 18 | tasbuget
# City not found. Skipping...
# Processing Record 35 of Set 18 | red wing
# Processing Record 36 of Set 18 | abalak
# Processing Record 37 of Set 18 | tonder
# Processing Record 38 of Set 18 | sisimiut
# Processing Record 39 of Set 18 | klaksvik
# Processing Record 40 of Set 18 | broome
# Processing Record 41 of Set 18 | popondetta
# Processing Record 42 of Set 18 | byron bay
# Processing Record 43 of Set 18 | calbuco
# Processing Record 44 of Set 18 | tarata
# Processing Record 45 of Set 18 | asau
# Processing Record 46 of Set 18 | kishapu
# Processing Record 47 of Set 18 | codrington
# Processing Record 48 of Set 18 | marienburg
# Processing Record 49 of Set 18 | batagay
# Processing Record 50 of Set 18 | mercedes
# Processing Record 1 of Set 19 | vaitupu
# City not found. Skipping...
# Processing Record 2 of Set 19 | hasaki
# Processing Record 3 of Set 19 | honiara
# Processing Record 4 of Set 19 | chilmari
# Processing Record 5 of Set 19 | mitsamiouli
# Processing Record 6 of Set 19 | lucea
# Processing Record 7 of Set 19 | los llanos de aridane
# Processing Record 8 of Set 19 | anadyr
# Processing Record 9 of Set 19 | acuna
# City not found. Skipping...
# Processing Record 10 of Set 19 | ballina
# Processing Record 11 of Set 19 | amapa
# Processing Record 12 of Set 19 | nelson bay
# Processing Record 13 of Set 19 | verkhnevilyuysk
# Processing Record 14 of Set 19 | grand gaube
# Processing Record 15 of Set 19 | longyearbyen
# Processing Record 16 of Set 19 | pisco
# Processing Record 17 of Set 19 | colac
# Processing Record 18 of Set 19 | farafangana
# Processing Record 19 of Set 19 | mahebourg
# Processing Record 20 of Set 19 | lyuban
# Processing Record 21 of Set 19 | kawana waters
# City not found. Skipping...
# Processing Record 22 of Set 19 | monte cristi
# City not found. Skipping...
# Processing Record 23 of Set 19 | mezen
# Processing Record 24 of Set 19 | halalo
# City not found. Skipping...
# Processing Record 25 of Set 19 | khani
# Processing Record 26 of Set 19 | takoradi
# Processing Record 27 of Set 19 | kahului
# Processing Record 28 of Set 19 | kuandian
# Processing Record 29 of Set 19 | kargopol
# Processing Record 30 of Set 19 | gat
# Processing Record 31 of Set 19 | adeje
# Processing Record 32 of Set 19 | xai-xai
# Processing Record 33 of Set 19 | swan hill
# Processing Record 34 of Set 19 | hithadhoo
# Processing Record 35 of Set 19 | henties bay
# Processing Record 36 of Set 19 | ixtapa
# Processing Record 37 of Set 19 | uwayl
# City not found. Skipping...
# Processing Record 38 of Set 19 | margate
# Processing Record 39 of Set 19 | bilma
# Processing Record 40 of Set 19 | tasiilaq
# Processing Record 41 of Set 19 | aitape
# Processing Record 42 of Set 19 | chicama
# Processing Record 43 of Set 19 | ovalle
# Processing Record 44 of Set 19 | ilulissat
# Processing Record 45 of Set 19 | qazanbulaq
# Processing Record 46 of Set 19 | namalenga
# Processing Record 47 of Set 19 | hervey bay
# Processing Record 48 of Set 19 | hilsa
# Processing Record 49 of Set 19 | alice springs
# Processing Record 50 of Set 19 | bantacan
# Processing Record 1 of Set 20 | yeletskiy
# City not found. Skipping...
# Processing Record 2 of Set 20 | makushino
# Processing Record 3 of Set 20 | sicamous
# Processing Record 4 of Set 20 | boyolangu
# Processing Record 5 of Set 20 | yellowknife
# Processing Record 6 of Set 20 | hamina
# Processing Record 7 of Set 20 | nome
# Processing Record 8 of Set 20 | lompoc
# Processing Record 9 of Set 20 | fukue
# Processing Record 10 of Set 20 | kimbe
# Processing Record 11 of Set 20 | iguape
# Processing Record 12 of Set 20 | kudahuvadhoo
# Processing Record 13 of Set 20 | rawson
# Processing Record 14 of Set 20 | san patricio
# Processing Record 15 of Set 20 | bathsheba
# Processing Record 16 of Set 20 | avera
# Processing Record 17 of Set 20 | dublin
# Processing Record 18 of Set 20 | hovd
# Processing Record 19 of Set 20 | kununurra
# Processing Record 20 of Set 20 | ancud
# Processing Record 21 of Set 20 | bam
# Processing Record 22 of Set 20 | salalah
# Processing Record 23 of Set 20 | affery
# Processing Record 24 of Set 20 | belushya guba
# City not found. Skipping...
# Processing Record 25 of Set 20 | nguiu
# City not found. Skipping...
# Processing Record 26 of Set 20 | kiruna
# Processing Record 27 of Set 20 | pangody
# Processing Record 28 of Set 20 | kutum
# Processing Record 29 of Set 20 | bethel
# Processing Record 30 of Set 20 | bajo baudo
# City not found. Skipping...
# Processing Record 31 of Set 20 | yulara
# Processing Record 32 of Set 20 | harnai
# Processing Record 33 of Set 20 | umzimvubu
# City not found. Skipping...
# Processing Record 34 of Set 20 | la romana
# Processing Record 35 of Set 20 | udachnyy
# Processing Record 36 of Set 20 | san andres
# Processing Record 37 of Set 20 | coquimbo
# Processing Record 38 of Set 20 | caravelas
# Processing Record 39 of Set 20 | goderich
# Processing Record 40 of Set 20 | moree
# Processing Record 41 of Set 20 | coihaique
# Processing Record 42 of Set 20 | khatanga
# Processing Record 43 of Set 20 | bogalusa
# Processing Record 44 of Set 20 | yarmouth
# Processing Record 45 of Set 20 | dera ismail khan
# Processing Record 46 of Set 20 | sassandra
# Processing Record 47 of Set 20 | gospic
# Processing Record 48 of Set 20 | qaqortoq
# Processing Record 49 of Set 20 | boa vista
# Processing Record 50 of Set 20 | rockland
# Processing Record 1 of Set 21 | avarua
# Processing Record 2 of Set 21 | jiaocheng
# Processing Record 3 of Set 21 | saint george
# Processing Record 4 of Set 21 | shihezi
# Processing Record 5 of Set 21 | tala
# Processing Record 6 of Set 21 | esperance
# Processing Record 7 of Set 21 | sirur
# Processing Record 8 of Set 21 | vila velha
# Processing Record 9 of Set 21 | fortuna
# Processing Record 10 of Set 21 | lasa
# Processing Record 11 of Set 21 | gorontalo
# Processing Record 12 of Set 21 | thompson
# Processing Record 13 of Set 21 | ferrol
# Processing Record 14 of Set 21 | sao jose da coroa grande
# Processing Record 15 of Set 21 | ketchikan
# Processing Record 16 of Set 21 | opuwo
# Processing Record 17 of Set 21 | willmar
# Processing Record 18 of Set 21 | moron
# Processing Record 19 of Set 21 | beyneu
# Processing Record 20 of Set 21 | banjar
# Processing Record 21 of Set 21 | monrovia
# Processing Record 22 of Set 21 | katherine
# Processing Record 23 of Set 21 | dwarka
# Processing Record 24 of Set 21 | solwezi
# Processing Record 25 of Set 21 | richards bay
# Processing Record 26 of Set 21 | mackenzie
# Processing Record 27 of Set 21 | mullaitivu
# City not found. Skipping...
# Processing Record 28 of Set 21 | chizhou
# Processing Record 29 of Set 21 | beringovskiy
# Processing Record 30 of Set 21 | ciras
# City not found. Skipping...
# Processing Record 31 of Set 21 | assiniboia
# Processing Record 32 of Set 21 | one hundred mile house
# City not found. Skipping...
# Processing Record 33 of Set 21 | natchez
# Processing Record 34 of Set 21 | vanavara
# Processing Record 35 of Set 21 | cherskiy
# Processing Record 36 of Set 21 | rio gallegos
# Processing Record 37 of Set 21 | elizabeth city
# Processing Record 38 of Set 21 | sosenskiy
# Processing Record 39 of Set 21 | kamenka
# Processing Record 40 of Set 21 | ankpa
# Processing Record 41 of Set 21 | port moresby
# Processing Record 42 of Set 21 | shaowu
# Processing Record 43 of Set 21 | ishigaki
# Processing Record 44 of Set 21 | palauig
# Processing Record 45 of Set 21 | sisophon
# Processing Record 46 of Set 21 | villarrica
# Processing Record 47 of Set 21 | mys shmidta
# City not found. Skipping...
# Processing Record 48 of Set 21 | opunake
# Processing Record 49 of Set 21 | nouadhibou
# Processing Record 50 of Set 21 | taoudenni
# Processing Record 1 of Set 22 | haines junction
# Processing Record 2 of Set 22 | manggar
# Processing Record 3 of Set 22 | bandarbeyla
# Processing Record 4 of Set 22 | beruwala
# Processing Record 5 of Set 22 | kavaratti
# Processing Record 6 of Set 22 | saryshagan
# City not found. Skipping...
# Processing Record 7 of Set 22 | bima
# Processing Record 8 of Set 22 | buraydah
# Processing Record 9 of Set 22 | todos santos
# Processing Record 10 of Set 22 | remedios
# Processing Record 11 of Set 22 | kracheh
# City not found. Skipping...
# Processing Record 12 of Set 22 | manado
# Processing Record 13 of Set 22 | saint-augustin
# Processing Record 14 of Set 22 | monte santo
# Processing Record 15 of Set 22 | arraial do cabo
# Processing Record 16 of Set 22 | roma
# Processing Record 17 of Set 22 | sitka
# Processing Record 18 of Set 22 | namibe
# Processing Record 19 of Set 22 | lastoursville
# Processing Record 20 of Set 22 | carutapera
# Processing Record 21 of Set 22 | longlac
# City not found. Skipping...
# Processing Record 22 of Set 22 | bahia blanca
# Processing Record 23 of Set 22 | kalmunai
# Processing Record 24 of Set 22 | paciran
# Processing Record 25 of Set 22 | labutta
# City not found. Skipping...
# Processing Record 26 of Set 22 | paamiut
# Processing Record 27 of Set 22 | peniche
# Processing Record 28 of Set 22 | north bend
# Processing Record 29 of Set 22 | port augusta
# Processing Record 30 of Set 22 | talara
# Processing Record 31 of Set 22 | wilmington
# Processing Record 32 of Set 22 | urucara
# Processing Record 33 of Set 22 | ranau
# Processing Record 34 of Set 22 | tilichiki
# Processing Record 35 of Set 22 | flin flon
# Processing Record 36 of Set 22 | makakilo city
# Processing Record 37 of Set 22 | balimo
# City not found. Skipping...
# Processing Record 38 of Set 22 | koszalin
# Processing Record 39 of Set 22 | baillif
# Processing Record 40 of Set 22 | nanortalik
# Processing Record 41 of Set 22 | muros
# Processing Record 42 of Set 22 | san cristobal
# Processing Record 43 of Set 22 | ghanzi
# Processing Record 44 of Set 22 | dordrecht
# Processing Record 45 of Set 22 | baoying
# Processing Record 46 of Set 22 | half moon bay
# Processing Record 47 of Set 22 | portland
# Processing Record 48 of Set 22 | laguna
# Processing Record 49 of Set 22 | nizhneyansk
# City not found. Skipping...
# Processing Record 50 of Set 22 | mount isa
# Processing Record 1 of Set 23 | saldanha
# Processing Record 2 of Set 23 | ondjiva
# Processing Record 3 of Set 23 | bollnas
# Processing Record 4 of Set 23 | umm kaddadah
# Processing Record 5 of Set 23 | jilin
# Processing Record 6 of Set 23 | hokitika
# Processing Record 7 of Set 23 | nam tha
# City not found. Skipping...
# Processing Record 8 of Set 23 | sao joao da barra
# Processing Record 9 of Set 23 | hami
# Processing Record 10 of Set 23 | kajaani
# Processing Record 11 of Set 23 | luebo
# Processing Record 12 of Set 23 | alofi
# Processing Record 13 of Set 23 | aleppo
# Processing Record 14 of Set 23 | soyo
# Processing Record 15 of Set 23 | katsuura
# Processing Record 16 of Set 23 | karratha
# Processing Record 17 of Set 23 | vysotskoye
# Processing Record 18 of Set 23 | zyryanka
# Processing Record 19 of Set 23 | tiksi
# Processing Record 20 of Set 23 | kenitra
# Processing Record 21 of Set 23 | ayr
# Processing Record 22 of Set 23 | kungurtug
# Processing Record 23 of Set 23 | saleaula
# City not found. Skipping...
# Processing Record 24 of Set 23 | fare
# Processing Record 25 of Set 23 | tubruq
# City not found. Skipping...
# Processing Record 26 of Set 23 | viedma
# Processing Record 27 of Set 23 | mora
# Processing Record 28 of Set 23 | pocone
# Processing Record 29 of Set 23 | mount gambier
# Processing Record 30 of Set 23 | general pico
# Processing Record 31 of Set 23 | agirish
# Processing Record 32 of Set 23 | emerald
# Processing Record 33 of Set 23 | bastrop
# Processing Record 34 of Set 23 | lakes entrance
# Processing Record 35 of Set 23 | grand river south east
# City not found. Skipping...
# Processing Record 36 of Set 23 | sukhobezvodnoye
# Processing Record 37 of Set 23 | vyritsa
# Processing Record 38 of Set 23 | luang prabang
# Processing Record 39 of Set 23 | port elizabeth
# Processing Record 40 of Set 23 | brae
# Processing Record 41 of Set 23 | santa cruz
# Processing Record 42 of Set 23 | sinjar
# Processing Record 43 of Set 23 | atambua
# Processing Record 44 of Set 23 | sokolo
# Processing Record 45 of Set 23 | sataua
# City not found. Skipping...
# Processing Record 46 of Set 23 | waddan
# Processing Record 47 of Set 23 | ridgecrest
# Processing Record 48 of Set 23 | aldan
# Processing Record 49 of Set 23 | onega
# Processing Record 50 of Set 23 | sao filipe
# Processing Record 1 of Set 24 | verkhnyaya inta
# Processing Record 2 of Set 24 | agadir
# Processing Record 3 of Set 24 | vanersborg
# Processing Record 4 of Set 24 | tornio
# Processing Record 5 of Set 24 | kurchum
# Processing Record 6 of Set 24 | sentyabrskiy
# City not found. Skipping...
# Processing Record 7 of Set 24 | skagastrond
# City not found. Skipping...
# Processing Record 8 of Set 24 | dingle
# Processing Record 9 of Set 24 | owak
# Processing Record 10 of Set 24 | englewood
# Processing Record 11 of Set 24 | chagda
# City not found. Skipping...
# Processing Record 12 of Set 24 | garowe
# Processing Record 13 of Set 24 | barentu
# Processing Record 14 of Set 24 | lisakovsk
# Processing Record 15 of Set 24 | meadow lake
# Processing Record 16 of Set 24 | aurora
# Processing Record 17 of Set 24 | tawkar
# City not found. Skipping...
# Processing Record 18 of Set 24 | yining
# Processing Record 19 of Set 24 | los alamos
# Processing Record 20 of Set 24 | buala
# Processing Record 21 of Set 24 | torzhok
# Processing Record 22 of Set 24 | husavik
# Processing Record 23 of Set 24 | macaubas
# Processing Record 24 of Set 24 | gumdag
# Processing Record 25 of Set 24 | safonovo
# Processing Record 26 of Set 24 | moerai
# Processing Record 27 of Set 24 | yuanping
# Processing Record 28 of Set 24 | robertsport
# Processing Record 29 of Set 24 | aswan
# Processing Record 30 of Set 24 | port hawkesbury
# Processing Record 31 of Set 24 | bosaso
# Processing Record 32 of Set 24 | pechenga
# Processing Record 33 of Set 24 | meulaboh
# Processing Record 34 of Set 24 | biak
# Processing Record 35 of Set 24 | jacqueville
# Processing Record 36 of Set 24 | cabra
# Processing Record 37 of Set 24 | fairbanks
# Processing Record 38 of Set 24 | naze
# Processing Record 39 of Set 24 | sterling
# Processing Record 40 of Set 24 | sorland
# Processing Record 41 of Set 24 | whangamata
# Processing Record 42 of Set 24 | esso
# Processing Record 43 of Set 24 | vila franca do campo
# Processing Record 44 of Set 24 | roald
# Processing Record 45 of Set 24 | doctor pedro p. pena
# City not found. Skipping...
# Processing Record 46 of Set 24 | kamina
# Processing Record 47 of Set 24 | varhaug
# Processing Record 48 of Set 24 | maragogi
# Processing Record 49 of Set 24 | bukachacha
# Processing Record 50 of Set 24 | kropotkin
# Processing Record 1 of Set 25 | hounde
# Processing Record 2 of Set 25 | gizo
# Processing Record 3 of Set 25 | inuvik
# Processing Record 4 of Set 25 | labuan
# Processing Record 5 of Set 25 | andenes
# Processing Record 6 of Set 25 | patamundai
# Processing Record 7 of Set 25 | barabai
# Processing Record 8 of Set 25 | severo-kurilsk
# Processing Record 9 of Set 25 | tura
# Processing Record 10 of Set 25 | fereydunshahr
# Processing Record 11 of Set 25 | athens
# Processing Record 12 of Set 25 | baykit
# Processing Record 13 of Set 25 | new richmond
# Processing Record 14 of Set 25 | komsomolskiy
# Processing Record 15 of Set 25 | princeton
# Processing Record 16 of Set 25 | tuatapere
# Processing Record 17 of Set 25 | lagoa
# Processing Record 18 of Set 25 | faya
# Processing Record 19 of Set 25 | pirapozinho
# Processing Record 20 of Set 25 | mormugao
# Processing Record 21 of Set 25 | khandwa
# Processing Record 22 of Set 25 | springhill
# Processing Record 23 of Set 25 | srikakulam
# Processing Record 24 of Set 25 | tungkang
# City not found. Skipping...
# Processing Record 25 of Set 25 | roura
# Processing Record 26 of Set 25 | poltavka
# Processing Record 27 of Set 25 | tautira
# Processing Record 28 of Set 25 | malartic
# Processing Record 29 of Set 25 | shizunai
# Processing Record 30 of Set 25 | toora-khem
# Processing Record 31 of Set 25 | gashua
# Processing Record 32 of Set 25 | galiwinku
# City not found. Skipping...
# Processing Record 33 of Set 25 | khingansk
# Processing Record 34 of Set 25 | nakusp
# Processing Record 35 of Set 25 | santo antonio de padua
# Processing Record 36 of Set 25 | naryan-mar
# Processing Record 37 of Set 25 | hofn
# Processing Record 38 of Set 25 | bengkulu
# Processing Record 39 of Set 25 | wajir
# Processing Record 40 of Set 25 | nemuro
# Processing Record 41 of Set 25 | beloha
# Processing Record 42 of Set 25 | haimen
# Processing Record 43 of Set 25 | westport
# Processing Record 44 of Set 25 | tutoia
# Processing Record 45 of Set 25 | leh
# Processing Record 46 of Set 25 | kifri
# Processing Record 47 of Set 25 | svetlaya
# Processing Record 48 of Set 25 | ust-omchug
# Processing Record 49 of Set 25 | polovinnoye
# Processing Record 50 of Set 25 | bababe
# City not found. Skipping...
# Processing Record 1 of Set 26 | nenita
# Processing Record 2 of Set 26 | key west
# Processing Record 3 of Set 26 | gursarai
# Processing Record 4 of Set 26 | vardo
# Processing Record 5 of Set 26 | yar-sale
# Processing Record 6 of Set 26 | aklavik
# Processing Record 7 of Set 26 | gusau
# Processing Record 8 of Set 26 | maumere
# Processing Record 9 of Set 26 | fort smith
# Processing Record 10 of Set 26 | khowai
# Processing Record 11 of Set 26 | zhuji
# Processing Record 12 of Set 26 | pokrovsk
# Processing Record 13 of Set 26 | anar darreh
# City not found. Skipping...
# Processing Record 14 of Set 26 | sitio novo do tocantins
# Processing Record 15 of Set 26 | vung tau
# Processing Record 16 of Set 26 | la macarena
# Processing Record 17 of Set 26 | antofagasta
# Processing Record 18 of Set 26 | tabas
# Processing Record 19 of Set 26 | toktogul
# Processing Record 20 of Set 26 | poddorye
# Processing Record 21 of Set 26 | milove
# Processing Record 22 of Set 26 | mayumba
# Processing Record 23 of Set 26 | cayenne
# Processing Record 24 of Set 26 | san quintin
# Processing Record 25 of Set 26 | mayskiy
# Processing Record 26 of Set 26 | tabialan
# City not found. Skipping...
# Processing Record 27 of Set 26 | taltal
# Processing Record 28 of Set 26 | vostok
# Processing Record 29 of Set 26 | puerto pinasco
# City not found. Skipping...
# Processing Record 30 of Set 26 | vangaindrano
# Processing Record 31 of Set 26 | poso
# Processing Record 32 of Set 26 | yakeshi
# Processing Record 33 of Set 26 | kormend
# Processing Record 34 of Set 26 | altamira
# Processing Record 35 of Set 26 | maxixe
# Processing Record 36 of Set 26 | aksarka
# Processing Record 37 of Set 26 | mishkino
# Processing Record 38 of Set 26 | orizona
# Processing Record 39 of Set 26 | wawa
# Processing Record 40 of Set 26 | liverpool
# Processing Record 41 of Set 26 | hihifo
# City not found. Skipping...
# Processing Record 42 of Set 26 | mrirt
# City not found. Skipping...
# Processing Record 43 of Set 26 | phek
# Processing Record 44 of Set 26 | mpulungu
# Processing Record 45 of Set 26 | nyurba
# Processing Record 46 of Set 26 | ulaanbaatar
# Processing Record 47 of Set 26 | guilin
# Processing Record 48 of Set 26 | basco
# Processing Record 49 of Set 26 | sarankhola
# Processing Record 50 of Set 26 | wanning
# Processing Record 1 of Set 27 | port blair
# Processing Record 2 of Set 27 | amboasary
# Processing Record 3 of Set 27 | grindavik
# Processing Record 4 of Set 27 | zhangjiakou
# Processing Record 5 of Set 27 | challans
# Processing Record 6 of Set 27 | verkhoyansk
# Processing Record 7 of Set 27 | pangnirtung
# Processing Record 8 of Set 27 | catalina
# Processing Record 9 of Set 27 | broken hill
# Processing Record 10 of Set 27 | montepuez
# Processing Record 11 of Set 27 | karpathos
# Processing Record 12 of Set 27 | rio grande
# Processing Record 13 of Set 27 | roebourne
# Processing Record 14 of Set 27 | guanica
# Processing Record 15 of Set 27 | tungor
# Processing Record 16 of Set 27 | stryn
# Processing Record 17 of Set 27 | sola
# Processing Record 18 of Set 27 | balad
# Processing Record 19 of Set 27 | raahe
# Processing Record 20 of Set 27 | lorengau
# Processing Record 21 of Set 27 | doha
# Processing Record 22 of Set 27 | tabiauea
# City not found. Skipping...
# Processing Record 23 of Set 27 | zaykovo
# Processing Record 24 of Set 27 | tunduru
# City not found. Skipping...
# Processing Record 25 of Set 27 | excelsior springs
# Processing Record 26 of Set 27 | slave lake
# Processing Record 27 of Set 27 | angoram
# Processing Record 28 of Set 27 | liancheng
# Processing Record 29 of Set 27 | ambulu
# Processing Record 30 of Set 27 | tayibe
# City not found. Skipping...
# Processing Record 31 of Set 27 | rabo de peixe
# Processing Record 32 of Set 27 | czarnkow
# Processing Record 33 of Set 27 | kuche
# City not found. Skipping...
# Processing Record 34 of Set 27 | pastavy
# Processing Record 35 of Set 27 | brownsville
# Processing Record 36 of Set 27 | zhanaozen
# Processing Record 37 of Set 27 | mayo
# Processing Record 38 of Set 27 | natal
# Processing Record 39 of Set 27 | chapada dos guimaraes
# Processing Record 40 of Set 27 | kualakapuas
# Processing Record 41 of Set 27 | havre-saint-pierre
# Processing Record 42 of Set 27 | sam roi yot
# Processing Record 43 of Set 27 | bonfim
# Processing Record 44 of Set 27 | pacific grove
# Processing Record 45 of Set 27 | baghdad
# Processing Record 46 of Set 27 | mananjary
# Processing Record 47 of Set 27 | chilca
# Processing Record 48 of Set 27 | kristiansund
# Processing Record 49 of Set 27 | high level
# Processing Record 50 of Set 27 | ahipara
# Processing Record 1 of Set 28 | peikang
# City not found. Skipping...
# Processing Record 2 of Set 28 | joshimath
# Processing Record 3 of Set 28 | brigantine
# Processing Record 4 of Set 28 | kailua
# Processing Record 5 of Set 28 | san joaquin
# Processing Record 6 of Set 28 | gravdal
# Processing Record 7 of Set 28 | ban phai
# Processing Record 8 of Set 28 | nadym
# Processing Record 9 of Set 28 | lavrentiya
# Processing Record 10 of Set 28 | fresnillo
# Processing Record 11 of Set 28 | cidreira
# Processing Record 12 of Set 28 | chatellerault
# Processing Record 13 of Set 28 | kovdor
# Processing Record 14 of Set 28 | bundi
# Processing Record 15 of Set 28 | beckley
# Processing Record 16 of Set 28 | ponta delgada
# Processing Record 17 of Set 28 | sumbawa
# City not found. Skipping...
# Processing Record 18 of Set 28 | mapiripan
# Processing Record 19 of Set 28 | zaysan
# Processing Record 20 of Set 28 | juye
# Processing Record 21 of Set 28 | imst
# Processing Record 22 of Set 28 | goundam
# Processing Record 23 of Set 28 | la rochelle
# Processing Record 24 of Set 28 | bukama
# Processing Record 25 of Set 28 | bisho
# Processing Record 26 of Set 28 | fairlie
# Processing Record 27 of Set 28 | kemin
# Processing Record 28 of Set 28 | panama city
# Processing Record 29 of Set 28 | bonthe
# Processing Record 30 of Set 28 | uniontown
# Processing Record 31 of Set 28 | ikalamavony
# Processing Record 32 of Set 28 | sawakin
# Processing Record 33 of Set 28 | guerrero negro
# Processing Record 34 of Set 28 | itubera
# Processing Record 35 of Set 28 | guantanamo
# Processing Record 36 of Set 28 | stuttgart
# Processing Record 37 of Set 28 | bira
# Processing Record 38 of Set 28 | tunxi
# City not found. Skipping...
# Processing Record 39 of Set 28 | espanola
# Processing Record 40 of Set 28 | marsa matruh
# Processing Record 41 of Set 28 | korla
# Processing Record 42 of Set 28 | luis correia
# Processing Record 43 of Set 28 | port hueneme
# Processing Record 44 of Set 28 | lubango
# Processing Record 45 of Set 28 | seminole
# Processing Record 46 of Set 28 | mmabatho
# Processing Record 47 of Set 28 | kwinana
# Processing Record 48 of Set 28 | kupang
# Processing Record 49 of Set 28 | nenjiang
# Processing Record 50 of Set 28 | beidao
# Processing Record 1 of Set 29 | schio
# Processing Record 2 of Set 29 | chernyshevskiy
# Processing Record 3 of Set 29 | putina
# Processing Record 4 of Set 29 | poya
# Processing Record 5 of Set 29 | goundi
# Processing Record 6 of Set 29 | taurage
# Processing Record 7 of Set 29 | cartagena del chaira
# Processing Record 8 of Set 29 | le port
# Processing Record 9 of Set 29 | pinega
# Processing Record 10 of Set 29 | hualmay
# Processing Record 11 of Set 29 | seara
# Processing Record 12 of Set 29 | mpika
# Processing Record 13 of Set 29 | cairns
# Processing Record 14 of Set 29 | toledo
# Processing Record 15 of Set 29 | yenagoa
# Processing Record 16 of Set 29 | labrea
# Processing Record 17 of Set 29 | malakal
# Processing Record 18 of Set 29 | port lincoln
# Processing Record 19 of Set 29 | kyra
# Processing Record 20 of Set 29 | vaitape
# Processing Record 21 of Set 29 | necochea
# Processing Record 22 of Set 29 | vestmannaeyjar
# Processing Record 23 of Set 29 | karamea
# City not found. Skipping...
# Processing Record 24 of Set 29 | qiongshan
# Processing Record 25 of Set 29 | coari
# Processing Record 26 of Set 29 | arandis
# Processing Record 27 of Set 29 | mtwara
# Processing Record 28 of Set 29 | scarborough
# Processing Record 29 of Set 29 | kologriv
# Processing Record 30 of Set 29 | maryborough
# Processing Record 31 of Set 29 | kuusamo
# Processing Record 32 of Set 29 | trairi
# Processing Record 33 of Set 29 | mantenopolis
# Processing Record 34 of Set 29 | narrabri
# Processing Record 35 of Set 29 | nuuk
# Processing Record 36 of Set 29 | alvorada
# Processing Record 37 of Set 29 | eldikan
# City not found. Skipping...
# Processing Record 38 of Set 29 | porto novo
# Processing Record 39 of Set 29 | abashiri
# Processing Record 40 of Set 29 | batagay-alyta
# Processing Record 41 of Set 29 | pella
# Processing Record 42 of Set 29 | yuli
# Processing Record 43 of Set 29 | palana
# Processing Record 44 of Set 29 | mabaruma
# Processing Record 45 of Set 29 | tezu
# Processing Record 46 of Set 29 | copiapo
# Processing Record 47 of Set 29 | zheleznodorozhnyy
# Processing Record 48 of Set 29 | sibolga
# Processing Record 49 of Set 29 | lafayette
# Processing Record 50 of Set 29 | kurilsk
# Processing Record 1 of Set 30 | alyangula
# Processing Record 2 of Set 30 | ilo
# Processing Record 3 of Set 30 | najran
# Processing Record 4 of Set 30 | dudinka
# Processing Record 5 of Set 30 | cockburn harbour
# City not found. Skipping...
# Processing Record 6 of Set 30 | nishihara
# Processing Record 7 of Set 30 | san policarpo
# Processing Record 8 of Set 30 | price
# Processing Record 9 of Set 30 | kumano
# Processing Record 10 of Set 30 | qasigiannguit
# Processing Record 11 of Set 30 | bilibino
# Processing Record 12 of Set 30 | yarada
# Processing Record 13 of Set 30 | souillac
# Processing Record 14 of Set 30 | berlevag
# Processing Record 15 of Set 30 | tagusao
# Processing Record 16 of Set 30 | shaoyang
# Processing Record 17 of Set 30 | inirida
# Processing Record 18 of Set 30 | dondo
# Processing Record 19 of Set 30 | padilla
# Processing Record 20 of Set 30 | liaozhong
# Processing Record 21 of Set 30 | huarmey
# Processing Record 22 of Set 30 | sabang
# Processing Record 23 of Set 30 | puerto leguizamo
# Processing Record 24 of Set 30 | sao luis do quitunde
# Processing Record 25 of Set 30 | ruatoria
# City not found. Skipping...
# Processing Record 26 of Set 30 | bolotnoye
# Processing Record 27 of Set 30 | malmyzh
# Processing Record 28 of Set 30 | nyrob
# Processing Record 29 of Set 30 | bondowoso
# Processing Record 30 of Set 30 | north las vegas
# Processing Record 31 of Set 30 | presidencia roque saenz pena
# Processing Record 32 of Set 30 | papantla
# City not found. Skipping...
# Processing Record 33 of Set 30 | shar
# Processing Record 34 of Set 30 | mecca
# Processing Record 35 of Set 30 | wattegama
# Processing Record 36 of Set 30 | touros
# Processing Record 37 of Set 30 | bur gabo
# City not found. Skipping...
# Processing Record 38 of Set 30 | gujan-mestras
# Processing Record 39 of Set 30 | moindou
# Processing Record 40 of Set 30 | tromso
# Processing Record 41 of Set 30 | sabzevar
# Processing Record 42 of Set 30 | toliary
# City not found. Skipping...
# Processing Record 43 of Set 30 | altamont
# Processing Record 44 of Set 30 | yumen
# Processing Record 45 of Set 30 | frankfurt
# Processing Record 46 of Set 30 | puri
# Processing Record 47 of Set 30 | lata
# Processing Record 48 of Set 30 | hobyo
# Processing Record 49 of Set 30 | okha
# Processing Record 50 of Set 30 | bull savanna
# Processing Record 1 of Set 31 | labuhan
# Processing Record 2 of Set 31 | kieta
# Processing Record 3 of Set 31 | kashi
# Processing Record 4 of Set 31 | skagen
# Processing Record 5 of Set 31 | tahoua
# Processing Record 6 of Set 31 | mandera
# Processing Record 7 of Set 31 | leshukonskoye
# Processing Record 8 of Set 31 | bara
# Processing Record 9 of Set 31 | sorong
# Processing Record 10 of Set 31 | hauterive
# Processing Record 11 of Set 31 | tual
# Processing Record 12 of Set 31 | nuristan
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#            City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0        Hailin  44.5833  129.4167      4.55        97         100
# 1       Ushuaia -54.8000  -68.3000     49.66        46          75
# 2  Constitucion -35.3333  -72.4167     68.95        64           5
# 3   Clyde River  70.4692  -68.5914    -12.77        77         100
# 4      Castanos  26.7833 -101.4167     55.35        31           0
# 5        Albany  42.6001  -73.9662     17.46        41          39
# 6   Forestville  38.8451  -76.8750     30.04        54          75
# 7        Dingli  35.8614   14.3822     55.81        82          20
# 8     Carnarvon -24.8667  113.6333     82.47        74           5
# 9          Hilo  19.7297 -155.0900     64.26        92         100
#
#    Wind Speed Country                 Date       Description
# 0        3.38      CN  2022-02-14 16:51:04   overcast clouds
# 1       16.11      AR  2022-02-14 16:51:04     broken clouds
# 2        8.61      CL  2022-02-14 16:51:05         clear sky
# 3       18.41      CA  2022-02-14 16:51:05        light snow
# 4        0.00      MX  2022-02-14 16:46:10         clear sky
# 5        5.01      US  2022-02-14 16:51:01  scattered clouds
# 6       10.36      US  2022-02-14 16:51:06     broken clouds
# 7        8.05      MT  2022-02-14 16:51:07        few clouds
# 8       10.36      AU  2022-02-14 16:51:07         clear sky
# 9        5.75      US  2022-02-14 16:46:55   overcast clouds

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
