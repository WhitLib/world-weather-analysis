# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
# Import the citipy module to determine city based on latitude and longitude
from citipy import citipy
# Import the API key
from config import weather_api_key
# Import the requests library
import requests
# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime

# %%
# Create a set of random latitude and longitude combinations
lat = np.random.uniform(low=-90.000, high=90.000, size=2000)
lng = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lng = zip(lat, lng)
lat_lng

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lng)

# %%
# Create an empty cities list
cities =[]

# Identify the nearest city for each lat and long combination
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 778

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=deb5b102a6498779b843effd893a5510

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in our list.
for i in range(len(cities)):

    # Group cities in sets of 25 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + cities[i]
    
# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 25 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_desc = str(city_weather["weather"][0]["description"])
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                            "Lat": city_lat,
                            "Lng": city_lng,
                            "Max Temp": city_max_temp,
                            "Humidity": city_humidity,
                            "Cloudiness": city_clouds,
                            "Wind Speed": city_wind,
                            "Country": city_country,
                            "Date": city_date,
                            "Description": city_desc,})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 16 | el cope
# Processing Record 2 of Set 16 | punta arenas
# Processing Record 3 of Set 16 | cabo san lucas
# Processing Record 4 of Set 16 | barrow
# Processing Record 5 of Set 16 | taoudenni
# Processing Record 6 of Set 16 | kapaa
# Processing Record 7 of Set 16 | hasaki
# Processing Record 8 of Set 16 | vaini
# Processing Record 9 of Set 16 | kavieng
# Processing Record 10 of Set 16 | hithadhoo
# Processing Record 11 of Set 16 | port elizabeth
# Processing Record 12 of Set 16 | busselton
# Processing Record 13 of Set 16 | coquimbo
# Processing Record 14 of Set 16 | ca mau
# Processing Record 15 of Set 16 | ahumada
# City not found. Skipping...
# Processing Record 16 of Set 16 | barentsburg
# City not found. Skipping...
# Processing Record 17 of Set 16 | suntar
# Processing Record 18 of Set 16 | salalah
# Processing Record 19 of Set 16 | nizhneyansk
# City not found. Skipping...
# Processing Record 20 of Set 16 | buraydah
# Processing Record 21 of Set 16 | sorland
# Processing Record 22 of Set 16 | tadine
# Processing Record 23 of Set 16 | ushuaia
# Processing Record 24 of Set 16 | tsihombe
# City not found. Skipping...
# Processing Record 25 of Set 16 | geraldton
# Processing Record 26 of Set 16 | plettenberg bay
# Processing Record 27 of Set 16 | bredasdorp
# Processing Record 28 of Set 16 | naze
# Processing Record 29 of Set 16 | atuona
# Processing Record 30 of Set 16 | albany
# Processing Record 31 of Set 16 | nemuro
# Processing Record 32 of Set 16 | touros
# Processing Record 33 of Set 16 | petrovsk-zabaykalskiy
# Processing Record 34 of Set 16 | sentyabrskiy
# City not found. Skipping...
# Processing Record 35 of Set 16 | itupiranga
# Processing Record 36 of Set 16 | ribeira grande
# Processing Record 37 of Set 16 | liverpool
# Processing Record 38 of Set 16 | cape town
# Processing Record 39 of Set 16 | bemidji
# Processing Record 40 of Set 16 | pontianak
# Processing Record 41 of Set 16 | cape coast
# Processing Record 42 of Set 16 | mount gambier
# Processing Record 43 of Set 16 | athens
# Processing Record 44 of Set 16 | lompoc
# Processing Record 45 of Set 16 | labuhan
# Processing Record 46 of Set 16 | chokurdakh
# Processing Record 47 of Set 16 | hobart
# Processing Record 48 of Set 16 | rikitea
# Processing Record 49 of Set 16 | upernavik
# Processing Record 50 of Set 16 | castro
# Processing Record 1 of Set 17 | bluff
# Processing Record 2 of Set 17 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 3 of Set 17 | saskylakh
# Processing Record 4 of Set 17 | kochubey
# Processing Record 5 of Set 17 | temaraia
# City not found. Skipping...
# Processing Record 6 of Set 17 | mataura
# Processing Record 7 of Set 17 | saleaula
# City not found. Skipping...
# Processing Record 8 of Set 17 | iskateley
# Processing Record 9 of Set 17 | naftah
# City not found. Skipping...
# Processing Record 10 of Set 17 | taolanaro
# City not found. Skipping...
# Processing Record 11 of Set 17 | bolungarvik
# City not found. Skipping...
# Processing Record 12 of Set 17 | hatillo
# Processing Record 13 of Set 17 | san patricio
# Processing Record 14 of Set 17 | clovis
# Processing Record 15 of Set 17 | tiksi
# Processing Record 16 of Set 17 | cidreira
# Processing Record 17 of Set 17 | ilulissat
# Processing Record 18 of Set 17 | new norfolk
# Processing Record 19 of Set 17 | omboue
# Processing Record 20 of Set 17 | raudeberg
# Processing Record 21 of Set 17 | grand river south east
# City not found. Skipping...
# Processing Record 22 of Set 17 | faanui
# Processing Record 23 of Set 17 | araouane
# Processing Record 24 of Set 17 | igrim
# Processing Record 25 of Set 17 | eyl
# Processing Record 26 of Set 17 | lagoa
# Processing Record 27 of Set 17 | talnakh
# Processing Record 28 of Set 17 | rawannawi
# City not found. Skipping...
# Processing Record 29 of Set 17 | puerto escondido
# Processing Record 30 of Set 17 | saldanha
# Processing Record 31 of Set 17 | tumannyy
# City not found. Skipping...
# Processing Record 32 of Set 17 | kalat
# Processing Record 33 of Set 17 | doha
# Processing Record 34 of Set 17 | alofi
# Processing Record 35 of Set 17 | port hardy
# Processing Record 36 of Set 17 | hermanus
# Processing Record 37 of Set 17 | longyearbyen
# Processing Record 38 of Set 17 | horconcitos
# Processing Record 39 of Set 17 | amapa
# Processing Record 40 of Set 17 | baker city
# Processing Record 41 of Set 17 | te anau
# Processing Record 42 of Set 17 | clarence town
# Processing Record 43 of Set 17 | mujiayingzi
# Processing Record 44 of Set 17 | allapalli
# Processing Record 45 of Set 17 | harper
# Processing Record 46 of Set 17 | dickson
# Processing Record 47 of Set 17 | san ramon
# Processing Record 48 of Set 17 | la ronge
# Processing Record 49 of Set 17 | mezen
# Processing Record 50 of Set 17 | berlevag
# Processing Record 1 of Set 18 | roebourne
# Processing Record 2 of Set 18 | yellowknife
# Processing Record 3 of Set 18 | tasiilaq
# Processing Record 4 of Set 18 | tuktoyaktuk
# Processing Record 5 of Set 18 | hilo
# Processing Record 6 of Set 18 | portland
# Processing Record 7 of Set 18 | mahebourg
# Processing Record 8 of Set 18 | rocha
# Processing Record 9 of Set 18 | belushya guba
# City not found. Skipping...
# Processing Record 10 of Set 18 | lucea
# Processing Record 11 of Set 18 | chuy
# Processing Record 12 of Set 18 | port lincoln
# Processing Record 13 of Set 18 | mayo
# Processing Record 14 of Set 18 | tarudant
# City not found. Skipping...
# Processing Record 15 of Set 18 | maldonado
# Processing Record 16 of Set 18 | puerto ayora
# Processing Record 17 of Set 18 | airai
# Processing Record 18 of Set 18 | pingzhuang
# Processing Record 19 of Set 18 | atambua
# Processing Record 20 of Set 18 | uddevalla
# Processing Record 21 of Set 18 | katangli
# Processing Record 22 of Set 18 | sorong
# Processing Record 23 of Set 18 | chakulia
# Processing Record 24 of Set 18 | cherskiy
# Processing Record 25 of Set 18 | jablah
# Processing Record 26 of Set 18 | bronnoysund
# Processing Record 27 of Set 18 | nhulunbuy
# Processing Record 28 of Set 18 | victoria
# Processing Record 29 of Set 18 | qaanaaq
# Processing Record 30 of Set 18 | port alfred
# Processing Record 31 of Set 18 | kodiak
# Processing Record 32 of Set 18 | barroualie
# City not found. Skipping...
# Processing Record 33 of Set 18 | tonj
# Processing Record 34 of Set 18 | vaitupu
# City not found. Skipping...
# Processing Record 35 of Set 18 | bethel
# Processing Record 36 of Set 18 | great yarmouth
# Processing Record 37 of Set 18 | camacha
# Processing Record 38 of Set 18 | envira
# Processing Record 39 of Set 18 | aklavik
# Processing Record 40 of Set 18 | vila velha
# Processing Record 41 of Set 18 | norman wells
# Processing Record 42 of Set 18 | hefei
# Processing Record 43 of Set 18 | thompson
# Processing Record 44 of Set 18 | hami
# Processing Record 45 of Set 18 | narsaq
# Processing Record 46 of Set 18 | brae
# Processing Record 47 of Set 18 | codrington
# Processing Record 48 of Set 18 | jamestown
# Processing Record 49 of Set 18 | toucheng
# Processing Record 50 of Set 18 | santa cruz del sur
# Processing Record 1 of Set 19 | attawapiskat
# City not found. Skipping...
# Processing Record 2 of Set 19 | kharan
# Processing Record 3 of Set 19 | pacific grove
# Processing Record 4 of Set 19 | carnarvon
# Processing Record 5 of Set 19 | nioro
# Processing Record 6 of Set 19 | butaritari
# Processing Record 7 of Set 19 | iquique
# Processing Record 8 of Set 19 | mar del plata
# Processing Record 9 of Set 19 | hastings
# Processing Record 10 of Set 19 | khatanga
# Processing Record 11 of Set 19 | boulder city
# Processing Record 12 of Set 19 | zhigansk
# Processing Record 13 of Set 19 | amderma
# City not found. Skipping...
# Processing Record 14 of Set 19 | storforshei
# Processing Record 15 of Set 19 | severo-kurilsk
# Processing Record 16 of Set 19 | sterling
# Processing Record 17 of Set 19 | yeniseysk
# Processing Record 18 of Set 19 | flinders
# Processing Record 19 of Set 19 | srednekolymsk
# Processing Record 20 of Set 19 | punta alta
# Processing Record 21 of Set 19 | panzhihua
# Processing Record 22 of Set 19 | souillac
# Processing Record 23 of Set 19 | mys shmidta
# City not found. Skipping...
# Processing Record 24 of Set 19 | inhambane
# Processing Record 25 of Set 19 | saint-philippe
# Processing Record 26 of Set 19 | gao
# Processing Record 27 of Set 19 | lasa
# Processing Record 28 of Set 19 | torbay
# Processing Record 29 of Set 19 | hokitika
# Processing Record 30 of Set 19 | alvorada
# Processing Record 31 of Set 19 | ocean city
# Processing Record 32 of Set 19 | nikolskoye
# Processing Record 33 of Set 19 | midyat
# Processing Record 34 of Set 19 | port said
# Processing Record 35 of Set 19 | yulara
# Processing Record 36 of Set 19 | najran
# Processing Record 37 of Set 19 | giyani
# Processing Record 38 of Set 19 | buguruslan
# Processing Record 39 of Set 19 | homer
# Processing Record 40 of Set 19 | kaeo
# Processing Record 41 of Set 19 | tezpur
# Processing Record 42 of Set 19 | tombouctou
# Processing Record 43 of Set 19 | ruatoria
# City not found. Skipping...
# Processing Record 44 of Set 19 | pundaguitan
# Processing Record 45 of Set 19 | maceio
# Processing Record 46 of Set 19 | teahupoo
# Processing Record 47 of Set 19 | borba
# Processing Record 48 of Set 19 | boguchany
# Processing Record 49 of Set 19 | mikhaylovka
# Processing Record 50 of Set 19 | yeppoon
# Processing Record 1 of Set 20 | pueblo rico
# Processing Record 2 of Set 20 | pangnirtung
# Processing Record 3 of Set 20 | kegayli
# City not found. Skipping...
# Processing Record 4 of Set 20 | benavente
# Processing Record 5 of Set 20 | coihaique
# Processing Record 6 of Set 20 | itarema
# Processing Record 7 of Set 20 | rogovskaya
# Processing Record 8 of Set 20 | caborca
# Processing Record 9 of Set 20 | bekhtery
# Processing Record 10 of Set 20 | arlit
# Processing Record 11 of Set 20 | bari
# Processing Record 12 of Set 20 | iqaluit
# Processing Record 13 of Set 20 | hofn
# Processing Record 14 of Set 20 | wakkanai
# Processing Record 15 of Set 20 | yatou
# Processing Record 16 of Set 20 | lyubeshiv
# City not found. Skipping...
# Processing Record 17 of Set 20 | broken hill
# Processing Record 18 of Set 20 | anadyr
# Processing Record 19 of Set 20 | high level
# Processing Record 20 of Set 20 | meulaboh
# Processing Record 21 of Set 20 | heihe
# Processing Record 22 of Set 20 | camapua
# Processing Record 23 of Set 20 | vostok
# Processing Record 24 of Set 20 | caraballeda
# Processing Record 25 of Set 20 | bilibino
# Processing Record 26 of Set 20 | deputatskiy
# Processing Record 27 of Set 20 | ulladulla
# Processing Record 28 of Set 20 | jalu
# Processing Record 29 of Set 20 | lazaro cardenas
# Processing Record 30 of Set 20 | ramasukha
# City not found. Skipping...
# Processing Record 31 of Set 20 | maniitsoq
# Processing Record 32 of Set 20 | senanga
# Processing Record 33 of Set 20 | golpayegan
# Processing Record 34 of Set 20 | nizamabad
# Processing Record 35 of Set 20 | manga
# Processing Record 36 of Set 20 | ciras
# City not found. Skipping...
# Processing Record 37 of Set 20 | kez
# Processing Record 38 of Set 20 | gladstone
# Processing Record 39 of Set 20 | sorvag
# City not found. Skipping...
# Processing Record 40 of Set 20 | turukhansk
# Processing Record 41 of Set 20 | hoquiam
# Processing Record 42 of Set 20 | talara
# Processing Record 43 of Set 20 | urozhayne
# City not found. Skipping...
# Processing Record 44 of Set 20 | guarapari
# Processing Record 45 of Set 20 | farmington
# Processing Record 46 of Set 20 | lebu
# Processing Record 47 of Set 20 | pevek
# Processing Record 48 of Set 20 | hinton
# Processing Record 49 of Set 20 | necochea
# Processing Record 50 of Set 20 | samarai
# Processing Record 1 of Set 21 | stoyba
# City not found. Skipping...
# Processing Record 2 of Set 21 | hervey bay
# Processing Record 3 of Set 21 | guerrero negro
# Processing Record 4 of Set 21 | qaqortoq
# Processing Record 5 of Set 21 | dikson
# Processing Record 6 of Set 21 | iranshahr
# Processing Record 7 of Set 21 | diffa
# Processing Record 8 of Set 21 | lundazi
# Processing Record 9 of Set 21 | praia
# Processing Record 10 of Set 21 | kaitangata
# Processing Record 11 of Set 21 | richards bay
# Processing Record 12 of Set 21 | poum
# Processing Record 13 of Set 21 | seoul
# Processing Record 14 of Set 21 | east london
# Processing Record 15 of Set 21 | sabha
# Processing Record 16 of Set 21 | dukat
# Processing Record 17 of Set 21 | klobuck
# Processing Record 18 of Set 21 | fernley
# Processing Record 19 of Set 21 | trairi
# Processing Record 20 of Set 21 | along
# Processing Record 21 of Set 21 | sokoni
# Processing Record 22 of Set 21 | arraial do cabo
# Processing Record 23 of Set 21 | horsham
# Processing Record 24 of Set 21 | ardahan
# Processing Record 25 of Set 21 | guaiuba
# Processing Record 26 of Set 21 | zhuanghe
# Processing Record 27 of Set 21 | georgetown
# Processing Record 28 of Set 21 | ekibastuz
# Processing Record 29 of Set 21 | avarua
# Processing Record 30 of Set 21 | sao filipe
# Processing Record 31 of Set 21 | hay river
# Processing Record 32 of Set 21 | adrar
# Processing Record 33 of Set 21 | mitilini
# City not found. Skipping...
# Processing Record 34 of Set 21 | kendari
# Processing Record 35 of Set 21 | bambous virieux
# Processing Record 36 of Set 21 | smolenka
# Processing Record 37 of Set 21 | prince rupert
# Processing Record 38 of Set 21 | comodoro rivadavia
# Processing Record 39 of Set 21 | ponta do sol
# Processing Record 40 of Set 21 | lorengau
# Processing Record 41 of Set 21 | murgab
# Processing Record 42 of Set 21 | tecoanapa
# Processing Record 43 of Set 21 | los llanos de aridane
# Processing Record 44 of Set 21 | aspindza
# Processing Record 45 of Set 21 | port moresby
# Processing Record 46 of Set 21 | sataua
# City not found. Skipping...
# Processing Record 47 of Set 21 | leninskoye
# Processing Record 48 of Set 21 | kazalinsk
# City not found. Skipping...
# Processing Record 49 of Set 21 | mahajanga
# Processing Record 50 of Set 21 | yaan
# Processing Record 1 of Set 22 | maiduguri
# Processing Record 2 of Set 22 | vestmanna
# Processing Record 3 of Set 22 | bur gabo
# City not found. Skipping...
# Processing Record 4 of Set 22 | ghanzi
# Processing Record 5 of Set 22 | bengkulu
# Processing Record 6 of Set 22 | aybak
# City not found. Skipping...
# Processing Record 7 of Set 22 | santa marta
# Processing Record 8 of Set 22 | saint-augustin
# Processing Record 9 of Set 22 | bolgar
# Processing Record 10 of Set 22 | skibbereen
# Processing Record 11 of Set 22 | tutoia
# Processing Record 12 of Set 22 | cockburn town
# Processing Record 13 of Set 22 | camabatela
# Processing Record 14 of Set 22 | zonguldak
# Processing Record 15 of Set 22 | jimma
# Processing Record 16 of Set 22 | palmer
# Processing Record 17 of Set 22 | antalaha
# Processing Record 18 of Set 22 | kloulklubed
# Processing Record 19 of Set 22 | broome
# Processing Record 20 of Set 22 | krasnoarmeysk
# Processing Record 21 of Set 22 | bohuslav
# Processing Record 22 of Set 22 | kudahuvadhoo
# Processing Record 23 of Set 22 | fortuna
# Processing Record 24 of Set 22 | ormara
# Processing Record 25 of Set 22 | chingirlau
# Processing Record 26 of Set 22 | kandete
# Processing Record 27 of Set 22 | kismayo
# Processing Record 28 of Set 22 | grand gaube
# Processing Record 29 of Set 22 | illintsi
# Processing Record 30 of Set 22 | besskorbnaya
# Processing Record 31 of Set 22 | dalvik
# Processing Record 32 of Set 22 | siuna
# Processing Record 33 of Set 22 | tunduru
# City not found. Skipping...
# Processing Record 34 of Set 22 | vila franca do campo
# Processing Record 35 of Set 22 | huanren
# Processing Record 36 of Set 22 | watertown
# Processing Record 37 of Set 22 | mukhanovo
# City not found. Skipping...
# Processing Record 38 of Set 22 | klyuchi
# Processing Record 39 of Set 22 | pipri
# Processing Record 40 of Set 22 | bonavista
# Processing Record 41 of Set 22 | aflu
# City not found. Skipping...
# Processing Record 42 of Set 22 | sur
# Processing Record 43 of Set 22 | zhangye
# Processing Record 44 of Set 22 | san cristobal
# Processing Record 45 of Set 22 | klaksvik
# Processing Record 46 of Set 22 | havoysund
# Processing Record 47 of Set 22 | asaka
# Processing Record 48 of Set 22 | nome
# Processing Record 49 of Set 22 | ancud
# Processing Record 50 of Set 22 | baruun-urt
# Processing Record 1 of Set 23 | lujiang
# Processing Record 2 of Set 23 | port-gentil
# Processing Record 3 of Set 23 | rio grande
# Processing Record 4 of Set 23 | nusaybin
# Processing Record 5 of Set 23 | ouesso
# Processing Record 6 of Set 23 | zapolyarnyy
# Processing Record 7 of Set 23 | saint anthony
# Processing Record 8 of Set 23 | jiangkou
# Processing Record 9 of Set 23 | omura
# Processing Record 10 of Set 23 | yerbogachen
# Processing Record 11 of Set 23 | isiro
# Processing Record 12 of Set 23 | ayorou
# Processing Record 13 of Set 23 | muswellbrook
# Processing Record 14 of Set 23 | cayenne
# Processing Record 15 of Set 23 | mackay
# Processing Record 16 of Set 23 | kahului
# Processing Record 17 of Set 23 | odesskoye
# Processing Record 18 of Set 23 | baghdad
# Processing Record 19 of Set 23 | petropavlovsk-kamchatskiy
# Processing Record 20 of Set 23 | kinshasa
# Processing Record 21 of Set 23 | laibin
# Processing Record 22 of Set 23 | olafsvik
# Processing Record 23 of Set 23 | kastamonu
# Processing Record 24 of Set 23 | sisimiut
# Processing Record 25 of Set 23 | vanimo
# Processing Record 26 of Set 23 | suoyarvi
# Processing Record 27 of Set 23 | saint-georges
# Processing Record 28 of Set 23 | mecca
# Processing Record 29 of Set 23 | port macquarie
# Processing Record 30 of Set 23 | estelle
# Processing Record 31 of Set 23 | manglaur
# Processing Record 32 of Set 23 | lamu
# Processing Record 33 of Set 23 | gaziantep
# Processing Record 34 of Set 23 | flin flon
# Processing Record 35 of Set 23 | lampa
# Processing Record 36 of Set 23 | redlands
# Processing Record 37 of Set 23 | gigmoto
# Processing Record 38 of Set 23 | constitucion
# Processing Record 39 of Set 23 | bathsheba
# Processing Record 40 of Set 23 | saint-pierre
# Processing Record 41 of Set 23 | zambezi
# Processing Record 42 of Set 23 | sechura
# Processing Record 43 of Set 23 | christchurch
# Processing Record 44 of Set 23 | sao jose da coroa grande
# Processing Record 45 of Set 23 | west bay
# Processing Record 46 of Set 23 | marawi
# Processing Record 47 of Set 23 | ambilobe
# Processing Record 48 of Set 23 | kadykchan
# City not found. Skipping...
# Processing Record 49 of Set 23 | tungor
# Processing Record 50 of Set 23 | bettendorf
# Processing Record 1 of Set 24 | ostrovnoy
# Processing Record 2 of Set 24 | sechelt
# Processing Record 3 of Set 24 | zolnoye
# City not found. Skipping...
# Processing Record 4 of Set 24 | tshane
# Processing Record 5 of Set 24 | henties bay
# Processing Record 6 of Set 24 | koumac
# Processing Record 7 of Set 24 | konevo
# Processing Record 8 of Set 24 | ahipara
# Processing Record 9 of Set 24 | myaundzha
# Processing Record 10 of Set 24 | rundu
# Processing Record 11 of Set 24 | hovd
# Processing Record 12 of Set 24 | yarmouth
# Processing Record 13 of Set 24 | morondava
# Processing Record 14 of Set 24 | marcona
# City not found. Skipping...
# Processing Record 15 of Set 24 | emba
# Processing Record 16 of Set 24 | honiara
# Processing Record 17 of Set 24 | timra
# Processing Record 18 of Set 24 | palembang
# Processing Record 19 of Set 24 | victor harbor
# Processing Record 20 of Set 24 | pisco
# Processing Record 21 of Set 24 | dunedin
# Processing Record 22 of Set 24 | itabera
# Processing Record 23 of Set 24 | clyde river
# Processing Record 24 of Set 24 | isoka
# Processing Record 25 of Set 24 | toulepleu
# City not found. Skipping...
# Processing Record 26 of Set 24 | laukaa
# Processing Record 27 of Set 24 | dondo
# Processing Record 28 of Set 24 | port blair
# Processing Record 29 of Set 24 | kroya
# Processing Record 30 of Set 24 | bundaberg
# Processing Record 31 of Set 24 | saint george
# Processing Record 32 of Set 24 | yumen
# Processing Record 33 of Set 24 | beyneu
# Processing Record 34 of Set 24 | sabang
# Processing Record 35 of Set 24 | viedma
# Processing Record 36 of Set 24 | berdigestyakh
# Processing Record 37 of Set 24 | markova
# Processing Record 38 of Set 24 | dzilam gonzalez
# Processing Record 39 of Set 24 | noyabrsk
# Processing Record 40 of Set 24 | burica
# City not found. Skipping...
# Processing Record 41 of Set 24 | marsh harbour
# Processing Record 42 of Set 24 | jabiru
# City not found. Skipping...
# Processing Record 43 of Set 24 | fairbanks
# Processing Record 44 of Set 24 | hengshan
# Processing Record 45 of Set 24 | chapais
# Processing Record 46 of Set 24 | ishinomaki
# Processing Record 47 of Set 24 | narragansett
# Processing Record 48 of Set 24 | zalesovo
# Processing Record 49 of Set 24 | ixtapa
# Processing Record 50 of Set 24 | tekeli
# Processing Record 1 of Set 25 | shimoda
# Processing Record 2 of Set 25 | tuy hoa
# Processing Record 3 of Set 25 | lubao
# Processing Record 4 of Set 25 | quatre cocos
# Processing Record 5 of Set 25 | balakhninskiy
# Processing Record 6 of Set 25 | nassau
# Processing Record 7 of Set 25 | kruisfontein
# Processing Record 8 of Set 25 | jieshi
# Processing Record 9 of Set 25 | port hedland
# Processing Record 10 of Set 25 | havre-saint-pierre
# Processing Record 11 of Set 25 | eirunepe
# Processing Record 12 of Set 25 | wamba
# Processing Record 13 of Set 25 | provideniya
# Processing Record 14 of Set 25 | kumi
# Processing Record 15 of Set 25 | valparaiso
# Processing Record 16 of Set 25 | kirkwall
# Processing Record 17 of Set 25 | umm lajj
# Processing Record 18 of Set 25 | albacete
# Processing Record 19 of Set 25 | ganganagar
# Processing Record 20 of Set 25 | esperance
# Processing Record 21 of Set 25 | two hills
# Processing Record 22 of Set 25 | songjianghe
# Processing Record 23 of Set 25 | svetlopolyansk
# Processing Record 24 of Set 25 | santa cruz de la palma
# Processing Record 25 of Set 25 | bella union
# Processing Record 26 of Set 25 | louisbourg
# City not found. Skipping...
# Processing Record 27 of Set 25 | belmonte
# Processing Record 28 of Set 25 | kedrovyy
# Processing Record 29 of Set 25 | praia da vitoria
# Processing Record 30 of Set 25 | elat
# Processing Record 31 of Set 25 | kosikha
# Processing Record 32 of Set 25 | camacupa
# Processing Record 33 of Set 25 | hailin
# Processing Record 34 of Set 25 | kishtwar
# Processing Record 35 of Set 25 | mitzic
# Processing Record 36 of Set 25 | chicama
# Processing Record 37 of Set 25 | egvekinot
# Processing Record 38 of Set 25 | bergheim
# Processing Record 39 of Set 25 | serenje
# Processing Record 40 of Set 25 | sena madureira
# Processing Record 41 of Set 25 | pandamatenga
# Processing Record 42 of Set 25 | mednogorsk
# Processing Record 43 of Set 25 | yuxia
# Processing Record 44 of Set 25 | acarau
# Processing Record 45 of Set 25 | takhtamygda
# Processing Record 46 of Set 25 | linxia
# Processing Record 47 of Set 25 | jha jha
# Processing Record 48 of Set 25 | dalgopol
# Processing Record 49 of Set 25 | kalmunai
# Processing Record 50 of Set 25 | arcos de la frontera
# Processing Record 1 of Set 26 | bayir
# Processing Record 2 of Set 26 | inverell
# Processing Record 3 of Set 26 | mareeba
# Processing Record 4 of Set 26 | yonago
# Processing Record 5 of Set 26 | otukpo
# Processing Record 6 of Set 26 | bacolod
# Processing Record 7 of Set 26 | zheleznodorozhnyy
# Processing Record 8 of Set 26 | zhezkazgan
# Processing Record 9 of Set 26 | afmadu
# City not found. Skipping...
# Processing Record 10 of Set 26 | liepaja
# Processing Record 11 of Set 26 | kendrapara
# Processing Record 12 of Set 26 | kurkino
# Processing Record 13 of Set 26 | jasper
# Processing Record 14 of Set 26 | the pas
# Processing Record 15 of Set 26 | tuatapere
# Processing Record 16 of Set 26 | churapcha
# Processing Record 17 of Set 26 | jiaocheng
# Processing Record 18 of Set 26 | aykhal
# Processing Record 19 of Set 26 | nantucket
# Processing Record 20 of Set 26 | suna
# Processing Record 21 of Set 26 | alyangula
# Processing Record 22 of Set 26 | frekhaug
# Processing Record 23 of Set 26 | chivay
# Processing Record 24 of Set 26 | bababe
# City not found. Skipping...
# Processing Record 25 of Set 26 | umzimvubu
# City not found. Skipping...
# Processing Record 26 of Set 26 | malatya
# Processing Record 27 of Set 26 | hambantota
# Processing Record 28 of Set 26 | north platte
# Processing Record 29 of Set 26 | tirumullaivasal
# Processing Record 30 of Set 26 | preobrazheniye
# Processing Record 31 of Set 26 | anantnag
# Processing Record 32 of Set 26 | puerto madero
# Processing Record 33 of Set 26 | ijaki
# City not found. Skipping...
# Processing Record 34 of Set 26 | beringovskiy
# Processing Record 35 of Set 26 | barybino
# Processing Record 36 of Set 26 | urusha
# Processing Record 37 of Set 26 | batemans bay
# Processing Record 38 of Set 26 | wabrzezno
# Processing Record 39 of Set 26 | pascagoula
# Processing Record 40 of Set 26 | petatlan
# Processing Record 41 of Set 26 | nizhniy kuranakh
# Processing Record 42 of Set 26 | alotau
# City not found. Skipping...
# Processing Record 43 of Set 26 | san antonio
# Processing Record 44 of Set 26 | padang
# Processing Record 45 of Set 26 | anamur
# Processing Record 46 of Set 26 | santa cruz
# Processing Record 47 of Set 26 | bac
# Processing Record 48 of Set 26 | klenovyy
# Processing Record 49 of Set 26 | nguiu
# City not found. Skipping...
# Processing Record 50 of Set 26 | mitsamiouli
# Processing Record 1 of Set 27 | malakal
# Processing Record 2 of Set 27 | husavik
# Processing Record 3 of Set 27 | watsa
# Processing Record 4 of Set 27 | vizinga
# Processing Record 5 of Set 27 | itum-kale
# Processing Record 6 of Set 27 | champerico
# Processing Record 7 of Set 27 | dianopolis
# City not found. Skipping...
# Processing Record 8 of Set 27 | asten
# Processing Record 9 of Set 27 | shahreza
# Processing Record 10 of Set 27 | sioux lookout
# Processing Record 11 of Set 27 | san andres
# Processing Record 12 of Set 27 | springbok
# Processing Record 13 of Set 27 | grand-lahou
# Processing Record 14 of Set 27 | aflao
# Processing Record 15 of Set 27 | abomey-calavi
# Processing Record 16 of Set 27 | cap malheureux
# Processing Record 17 of Set 27 | batticaloa
# Processing Record 18 of Set 27 | goderich
# Processing Record 19 of Set 27 | gat
# Processing Record 20 of Set 27 | sri aman
# Processing Record 21 of Set 27 | constantine
# Processing Record 22 of Set 27 | thaba-tseka
# Processing Record 23 of Set 27 | ponta delgada
# Processing Record 24 of Set 27 | penzberg
# Processing Record 25 of Set 27 | polonnaruwa
# Processing Record 26 of Set 27 | arkhangelsk
# Processing Record 27 of Set 27 | rudnogorsk
# Processing Record 28 of Set 27 | port augusta
# Processing Record 29 of Set 27 | baykit
# Processing Record 30 of Set 27 | burnie
# Processing Record 31 of Set 27 | altamira
# Processing Record 32 of Set 27 | araguatins
# City not found. Skipping...
# Processing Record 33 of Set 27 | storsteinnes
# Processing Record 34 of Set 27 | yangambi
# Processing Record 35 of Set 27 | armacao dos buzios
# City not found. Skipping...
# Processing Record 36 of Set 27 | rio gallegos
# Processing Record 37 of Set 27 | ronneby
# Processing Record 38 of Set 27 | chumikan
# Processing Record 39 of Set 27 | palabuhanratu
# City not found. Skipping...
# Processing Record 40 of Set 27 | itaituba
# Processing Record 41 of Set 27 | choszczno
# Processing Record 42 of Set 27 | dymer
# Processing Record 43 of Set 27 | biak
# Processing Record 44 of Set 27 | bay roberts
# Processing Record 45 of Set 27 | nanortalik
# Processing Record 46 of Set 27 | khandyga
# Processing Record 47 of Set 27 | kabacan
# Processing Record 48 of Set 27 | bud
# Processing Record 49 of Set 27 | bosaso
# Processing Record 50 of Set 27 | bowen
# Processing Record 1 of Set 28 | san quintin
# Processing Record 2 of Set 28 | dingle
# Processing Record 3 of Set 28 | coahuayana
# Processing Record 4 of Set 28 | dryden
# Processing Record 5 of Set 28 | nanga eboko
# Processing Record 6 of Set 28 | acapulco
# Processing Record 7 of Set 28 | okhotsk
# Processing Record 8 of Set 28 | nogliki
# Processing Record 9 of Set 28 | gorontalo
# Processing Record 10 of Set 28 | moyale
# Processing Record 11 of Set 28 | leshukonskoye
# Processing Record 12 of Set 28 | varadero
# Processing Record 13 of Set 28 | yar-sale
# Processing Record 14 of Set 28 | voh
# Processing Record 15 of Set 28 | guthrie
# Processing Record 16 of Set 28 | katsuura
# Processing Record 17 of Set 28 | kendal
# Processing Record 18 of Set 28 | tokur
# Processing Record 19 of Set 28 | paradwip
# City not found. Skipping...
# Processing Record 20 of Set 28 | faya
# Processing Record 21 of Set 28 | chimoio
# Processing Record 22 of Set 28 | lakes entrance
# Processing Record 23 of Set 28 | lyuban
# Processing Record 24 of Set 28 | khasan
# Processing Record 25 of Set 28 | huarmey
# Processing Record 26 of Set 28 | teruel
# Processing Record 27 of Set 28 | sosnovo-ozerskoye
# Processing Record 28 of Set 28 | dong hoi
# Processing Record 29 of Set 28 | sokoto
# Processing Record 30 of Set 28 | gari
# Processing Record 31 of Set 28 | krasnyy kut
# Processing Record 32 of Set 28 | tura
# Processing Record 33 of Set 28 | dalbandin
# Processing Record 34 of Set 28 | hobyo
# Processing Record 35 of Set 28 | puerto el triunfo
# Processing Record 36 of Set 28 | takoradi
# Processing Record 37 of Set 28 | tabiauea
# City not found. Skipping...
# Processing Record 38 of Set 28 | caravelas
# Processing Record 39 of Set 28 | kokopo
# Processing Record 40 of Set 28 | balkanabat
# Processing Record 41 of Set 28 | jutai
# Processing Record 42 of Set 28 | bocicoiu mare
# Processing Record 43 of Set 28 | maturin
# Processing Record 44 of Set 28 | oga
# Processing Record 45 of Set 28 | sainte-anne-des-monts
# Processing Record 46 of Set 28 | tuzha
# Processing Record 47 of Set 28 | beinamar
# Processing Record 48 of Set 28 | kabompo
# Processing Record 49 of Set 28 | fallon
# Processing Record 50 of Set 28 | karratha
# Processing Record 1 of Set 29 | ilo
# Processing Record 2 of Set 29 | usinsk
# Processing Record 3 of Set 29 | jucuaran
# Processing Record 4 of Set 29 | manado
# Processing Record 5 of Set 29 | okha
# Processing Record 6 of Set 29 | neverkino
# Processing Record 7 of Set 29 | ambanja
# Processing Record 8 of Set 29 | namibe
# Processing Record 9 of Set 29 | buenos aires
# Processing Record 10 of Set 29 | ambon
# Processing Record 11 of Set 29 | tortoli
# Processing Record 12 of Set 29 | muisne
# Processing Record 13 of Set 29 | halifax
# Processing Record 14 of Set 29 | sept-iles
# Processing Record 15 of Set 29 | ternate
# Processing Record 16 of Set 29 | camopi
# Processing Record 17 of Set 29 | ovalle
# Processing Record 18 of Set 29 | evensk
# Processing Record 19 of Set 29 | stephenville
# Processing Record 20 of Set 29 | olinda
# Processing Record 21 of Set 29 | sinjah
# City not found. Skipping...
# Processing Record 22 of Set 29 | bayan
# Processing Record 23 of Set 29 | nizhniy odes
# Processing Record 24 of Set 29 | sulangan
# Processing Record 25 of Set 29 | namatanai
# Processing Record 26 of Set 29 | bintulu
# Processing Record 27 of Set 29 | wajima
# Processing Record 28 of Set 29 | crab hill
# City not found. Skipping...
# Processing Record 29 of Set 29 | bull savanna
# Processing Record 30 of Set 29 | peniche
# Processing Record 31 of Set 29 | fort nelson
# Processing Record 32 of Set 29 | praya
# Processing Record 33 of Set 29 | dallas
# Processing Record 34 of Set 29 | quime
# Processing Record 35 of Set 29 | pitimbu
# Processing Record 36 of Set 29 | anloga
# Processing Record 37 of Set 29 | luderitz
# Processing Record 38 of Set 29 | mahon
# Processing Record 39 of Set 29 | asau
# Processing Record 40 of Set 29 | flagstaff
# Processing Record 41 of Set 29 | maksatikha
# Processing Record 42 of Set 29 | tidore
# City not found. Skipping...
# Processing Record 43 of Set 29 | camacari
# Processing Record 44 of Set 29 | williams lake
# Processing Record 45 of Set 29 | sacele
# Processing Record 46 of Set 29 | ankara
# Processing Record 47 of Set 29 | amarillo
# Processing Record 48 of Set 29 | donskoye
# Processing Record 49 of Set 29 | nioki
# Processing Record 50 of Set 29 | west odessa
# Processing Record 1 of Set 30 | sidmouth
# Processing Record 2 of Set 30 | grindavik
# Processing Record 3 of Set 30 | soure
# Processing Record 4 of Set 30 | fare
# Processing Record 5 of Set 30 | vao
# Processing Record 6 of Set 30 | honningsvag
# Processing Record 7 of Set 30 | lolua
# City not found. Skipping...
# Processing Record 8 of Set 30 | tel aviv-yafo
# Processing Record 9 of Set 30 | san policarpo
# Processing Record 10 of Set 30 | tazovskiy
# Processing Record 11 of Set 30 | bajo baudo
# City not found. Skipping...
# Processing Record 12 of Set 30 | yuzhno-yeniseyskiy
# City not found. Skipping...
# Processing Record 13 of Set 30 | escanaba
# Processing Record 14 of Set 30 | tome-acu
# City not found. Skipping...
# Processing Record 15 of Set 30 | khuzhir
# Processing Record 16 of Set 30 | aitape
# Processing Record 17 of Set 30 | warqla
# City not found. Skipping...
# Processing Record 18 of Set 30 | sistranda
# Processing Record 19 of Set 30 | krasne
# Processing Record 20 of Set 30 | mnogovershinnyy
# Processing Record 21 of Set 30 | kondratovo
# Processing Record 22 of Set 30 | dujuma
# City not found. Skipping...
# Processing Record 23 of Set 30 | astorga
# Processing Record 24 of Set 30 | chiang rai
# Processing Record 25 of Set 30 | bubaque
# Processing Record 26 of Set 30 | hihifo
# City not found. Skipping...
# Processing Record 27 of Set 30 | howard springs
# Processing Record 28 of Set 30 | raga
# Processing Record 29 of Set 30 | tomatlan
# Processing Record 30 of Set 30 | san clemente
# Processing Record 31 of Set 30 | sao joao da barra
# Processing Record 32 of Set 30 | vaitape
# Processing Record 33 of Set 30 | icanti
# City not found. Skipping...
# Processing Record 34 of Set 30 | katsiveli
# City not found. Skipping...
# Processing Record 35 of Set 30 | pindushi
# Processing Record 36 of Set 30 | dawlatabad
# Processing Record 37 of Set 30 | teguldet
# Processing Record 38 of Set 30 | porto nacional
# Processing Record 39 of Set 30 | mubi
# Processing Record 40 of Set 30 | shitanjing
# Processing Record 41 of Set 30 | mangan
# Processing Record 42 of Set 30 | mayor pablo lagerenza
# Processing Record 43 of Set 30 | melito di porto salvo
# Processing Record 44 of Set 30 | pedasi
# Processing Record 45 of Set 30 | chagda
# City not found. Skipping...
# Processing Record 46 of Set 30 | ust-kuyga
# Processing Record 47 of Set 30 | beaverlodge
# Processing Record 48 of Set 30 | otane
# Processing Record 49 of Set 30 | sal rei
# Processing Record 50 of Set 30 | alto araguaia
# Processing Record 1 of Set 31 | amahai
# Processing Record 2 of Set 31 | oinofita
# City not found. Skipping...
# Processing Record 3 of Set 31 | boralday
# Processing Record 4 of Set 31 | general roca
# Processing Record 5 of Set 31 | poya
# Processing Record 6 of Set 31 | santa catalina
# Processing Record 7 of Set 31 | gobabis
# Processing Record 8 of Set 31 | kautokeino
# Processing Record 9 of Set 31 | point fortin
# Processing Record 10 of Set 31 | azad shahr
# Processing Record 11 of Set 31 | mocorito
# Processing Record 12 of Set 31 | seversk
# Processing Record 13 of Set 31 | rawson
# Processing Record 14 of Set 31 | xuddur
# Processing Record 15 of Set 31 | grand-santi
# Processing Record 16 of Set 31 | qui nhon
# Processing Record 17 of Set 31 | xiongzhou
# Processing Record 18 of Set 31 | tartagal
# Processing Record 19 of Set 31 | mayfield
# Processing Record 20 of Set 31 | sitka
# Processing Record 21 of Set 31 | okato
# Processing Record 22 of Set 31 | maningrida
# Processing Record 23 of Set 31 | pangkalanbuun
# Processing Record 24 of Set 31 | shergarh
# Processing Record 25 of Set 31 | akureyri
# Processing Record 26 of Set 31 | toyooka
# Processing Record 27 of Set 31 | tevaitoa
# Processing Record 28 of Set 31 | irituia
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#              City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0         El Cope   8.6167  -80.6000     78.26        54          28
# 1    Punta Arenas -53.1500  -70.9167     50.11        50          40
# 2  Cabo San Lucas  22.8909 -109.9124     85.30        56          75
# 3          Barrow  71.2906 -156.7887    -29.18       100           0
# 4       Taoudenni  22.6783   -3.9836     66.18        22           0
# 5           Kapaa  22.0752 -159.3190     76.12        72          40
# 6          Hasaki  35.7333  140.8333     36.00        92         100
# 7           Vaini -21.2000 -175.2000     80.62        76          77
# 8         Kavieng  -2.5744  150.7967     80.74        78          96
# 9       Hithadhoo  -0.6000   73.0833     82.15        75          67
#
#    Wind Speed Country                 Date       Description
# 0       11.43      PA  2022-02-13 20:09:28  scattered clouds
# 1       31.07      CL  2022-02-13 20:09:29  scattered clouds
# 2        8.05      MX  2022-02-13 20:09:29     broken clouds
# 3        8.05      US  2022-02-13 20:09:30         clear sky
# 4       11.59      ML  2022-02-13 20:09:30         clear sky
# 5       13.80      US  2022-02-13 20:09:31  scattered clouds
# 6       33.24      JP  2022-02-13 20:05:41   overcast clouds
# 7       18.43      TO  2022-02-13 20:05:29        light rain
# 8        6.80      PG  2022-02-13 20:09:31   overcast clouds
# 9        9.46      MV  2022-02-13 20:09:32     broken clouds

# %%
# Create the output file (CSV).
output_data_file = "weather_database/WeatherPy_database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /var/folders/j8/50f6g2zx6r5_6918_dltg93h0000gn/T/ipykernel_11877/3023075448.py in <module>
#       2 output_data_file = "weather_database/WeatherPy_database.csv"
#       3 # Export the City_Data into a CSV.
# ----> 4 city_data_df.to_csv(output_data_file, index_label="City_ID")
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/generic.py in to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, line_terminator, chunksize, date_format, doublequote, escapechar, decimal, errors, storage_options)
#    3464         )
#    3465
# -> 3466         return DataFrameRenderer(formatter).to_csv(
#    3467             path_or_buf,
#    3468             line_terminator=line_terminator,
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/io/formats/format.py in to_csv(self, path_or_buf, encoding, sep, columns, index_label, mode, compression, quoting, quotechar, line_terminator, chunksize, date_format, doublequote, escapechar, errors, storage_options)
#    1103             formatter=self.fmt,
#    1104         )
# -> 1105         csv_formatter.save()
#    1106
#    1107         if created_buffer:
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/io/formats/csvs.py in save(self)
#     235         """
#     236         # apply compression and byte/text conversion
# --> 237         with get_handle(
#     238             self.filepath_or_buffer,
#     239             self.mode,
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/io/common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     700         if ioargs.encoding and "b" not in ioargs.mode:
#     701             # Encoding
# --> 702             handle = open(
#     703                 handle,
#     704                 ioargs.mode,
#
# FileNotFoundError: [Errno 2] No such file or directory: 'weather_database/WeatherPy_database.csv'
